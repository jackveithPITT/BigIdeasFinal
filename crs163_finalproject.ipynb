# %%
import pandas as pd

court = pd.read_csv("Final-Project/courtsAndRinks.csv")
court.head(246)
# Out:
#              id                                   name               type  \
# 0    1592343416   Allegheny Commons Basketball Court 1  Basketball (Full)
# 1    1365248699  Allegheny Commons Park Tennis Court 1             Tennis
# 2    1757180821  Allegheny Commons Park Tennis Court 2             Tennis
# 3     744303307  Allegheny Commons Park Tennis Court 3             Tennis
# 4    1157777481          Alton Park Basketball Court 1  Basketball (Half)
# ..          ...                                    ...                ...
# 241  1256692000          Riverview Park Tennis Court 2             Tennis
# 242  1802795636         West End Park Basketball Court  Basketball (Half)
# 243   529313558          Frick Park Pickleball Court 1         Pickleball
# 244  1330544431          Frick Park Pickleball Court 2         Pickleball
# 245    30730620          Frick Park Pickleball Court 3         Pickleball
#
#                   park location surface_material  grandstand inactive  \
# ...

# %%
print(court["type"].unique())
court["type"].nunique()
# Out:
# ['Basketball (Full)' 'Tennis' 'Basketball (Half)' 'General Sports'
#  'Street Hockey' 'Dek Hockey' 'Hockey' 'Pickleball' 'Volleyball'
#  'Lawn Bowling' 'Bocce' 'Horseshoe Pit']
# 12

# %%
print(court["name"].unique())
court["name"].nunique()
# Out:
# ['Allegheny Commons Basketball Court 1'
#  'Allegheny Commons Park Tennis Court 1'
#  'Allegheny Commons Park Tennis Court 2'
#  'Allegheny Commons Park Tennis Court 3' 'Alton Park Basketball Court 1'
#  'Alton Park Basketball Court 2' 'Ammon Park Basketball Court 1'
#  'Ammon Park Basketball Court 2' 'Arlington Park Basketball Court 1'
#  'Armstrong Park Basketball Court 1' 'Armstrong Park Sports Court 1'
#  'Arsenal Basketball Court 1' 'Arsenal Hockey Court 1'
#  'Arsenal Park Tennis Court 1' 'Arsenal Park Tennis Court 2'
#  'Arsenal Park Tennis Court 3' 'Arsenal Park Tennis Court 4'
#  'August Wilson Park Basketball Court 1'
#  'Banksville Park Basketball Court 1' 'Banksville Park Dek Hockey Court 1'
#  'Banksville Park Tennis Court 1' 'Bon Air Park Hockey Court 1'
#  'Boundary Street Park Hockey Court 1'
#  'Brighton Heights Park Basketball Court 1'
#  'Brookline Memorial Park Basketball Court 1'
#  'Brookline Memorial Park Dek Hockey Court 1'
# ...

# %%
print(court["neighborhood"].unique())
court["neighborhood"].nunique()
# Out:
# ['Allegheny Center' 'Beechview' 'Bedford Dwellings' 'South Side Slopes'
#  'South Side Flats' 'Lower Lawrenceville' 'Crawford-Roberts' 'Banksville'
#  'Bon Air' 'Central Oakland' 'Brighton Heights' 'Brookline' 'Hazelwood'
#  'Lincoln-Lemington-Belmar' 'Troy Hill' 'Perry South' 'Homewood West'
#  'Squirrel Hill South' 'Strip District' 'Stanton Heights'
#  'Crafton Heights' 'Upper Lawrenceville' 'East Carnegie' 'East Hills'
#  'Duquesne Heights' 'Allentown' 'Mount Washington' 'East Liberty'
#  'Fairywood' 'Fineview' 'Garfield' 'Greenfield' 'South Oakland'
#  'Point Breeze' 'Regent Square' 'Hays' 'Elliott' 'Morningside'
#  'Highland Park' 'Central Northside' 'Terrace Village' 'Larimer'
#  'Spring Hill-City View' 'Carrick' 'Central Lawrenceville' 'Manchester'
#  'Marshall-Shadeland' 'Lincoln Place' 'Sheraden' 'Beltzhoover' 'Shadyside'
#  'Oakwood' 'Bloomfield' 'Upper Hill' 'New Homestead' 'Spring Garden'
#  'Middle Hill' 'West End' 'Polish Hill' 'Squirrel Hill North'
# ...

# %%
court['neighborhood'].value_counts()
# Out:
# Squirrel Hill South      26
# Highland Park            20
# Hazelwood                10
# Beltzhoover               9
# Brookline                 9
#                          ..
# Upper Hill                1
# Hays                      1
# Marshall-Shadeland        1
# Perry South               1
# Central Lawrenceville     1
# Name: neighborhood, Length: 63, dtype: int64
